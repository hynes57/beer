# %%
import pandas as pd

data = pd.read_stata("../data/breweries_to_use_1.dta")

# %%
sample = data.sample(50)

# %%
sample
# Out:
#        brewery_id                         brewery_name
# 37285      170344                     Ballston Brewery  \
# 43788         187                    Brasserie du Bocq
# 41741       17785       Domaine du Manoir de Montreuil
# 15411      128823           ThumbCoast Brewing Company
# 27010      151146                     Big Man Brewing
# 10896      120066                  CervecerÃ­a Vintage
# 50903       29643                            KrakonoÅ¡
# 39703      174453                       My Beer Friend
# 81086       89229                     Shoes Brews Ohio
# 31612      159944                           Glidewell
# 78167       83727                       Spiral Brewery
# 10861      119989       Last Best Brewing & Distilling
# 72144       71331                           RN Brewing
# 60168       47950                         Curtis Brews
# 85500       97301          Paul Bunyan Brewing Company
# 62037       51520              Brouwerij Hettinga Bier
# ...

# %%
examples = [
    ('Who is Shaka Khan?',
     {(7, 17, 'PERSON')}),
    ('I like London and Berlin.',
     {(7, 13, 'LOC'), (18, 24, 'LOC')})
]

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %%
nlp.meta["performance"]["ents_per_type"]
# Out:
# {'DATE': {'p': 0.8603213844, 'r': 0.8838095238, 'f': 0.8719072972},
#  'GPE': {'p': 0.9146932953, 'r': 0.8942817294000001, 'f': 0.9043723554},
#  'ORG': {'p': 0.7955942623000001, 'r': 0.8234358431000001, 'f': 0.8092756644},
#  'CARDINAL': {'p': 0.8149171271000001,
#   'r': 0.8769322235,
#   'f': 0.8447880871000001},
#  'PERSON': {'p': 0.8617758186000001, 'r': 0.8932767624, 'f': 0.8772435897},
#  'NORP': {'p': 0.8957006369, 'r': 0.9, 'f': 0.8978451716},
#  'ORDINAL': {'p': 0.7844827586, 'r': 0.8478260870000001, 'f': 0.8149253731},
#  'QUANTITY': {'p': 0.8529411765, 'r': 0.6373626374, 'f': 0.7295597484},
#  'LOC': {'p': 0.7210884354, 'r': 0.6751592357, 'f': 0.6973684211000001},
#  'FAC': {'p': 0.358490566, 'r': 0.29230769230000003, 'f': 0.3220338983},
#  'TIME': {'p': 0.7413793103, 'r': 0.7543859649, 'f': 0.7478260870000001},
#  'PRODUCT': {'p': 0.5591397849, 'r': 0.2464454976, 'f': 0.3421052632},
#  'WORK_OF_ART': {'p': 0.48854961830000004,
#   'r': 0.32989690720000003,
# ...
